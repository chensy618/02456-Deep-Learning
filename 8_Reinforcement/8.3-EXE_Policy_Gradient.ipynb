# %% [markdown]
# # Solve cartpole with REINFORCE
#
# > By Jonas Busk ([jbusk@dtu.dk](mailto:jbusk@dtu.dk))
#
# **2019 update:** Changes have been made to the display of environments due to the previous `viewer` being incompatible with newer versions of Gym.
#
# **2022 update:** Rendering was disabled, and the notebook now uses the `colabgymrender` package to render a video.
#
# **2023 update:** Changed to packages `gymnasium` and `renderlab`, and to `CartPole-v1`.
#
# In this part, we will create an agent that can learn to solve the [cartpole problem](https://gymnasium.farama.org/environments/classic_control/cart_pole/) from OpenAI Gym by applying a simple policy gradient method called REINFORCE.
# In the cartpole problem, we need to balance a pole on a cart that moves along a track by applying left and right forces to the cart.
#
# We will implement a probabilistic policy, that given a state of the environment, $s$, outputs a probability distribution over available actions, $a$:
#
# $$
# p_\theta(a|s)
# $$
#
# The policy is a neural network with parameters $\theta$ that can be trained with gradient descent.
# When the set of available actions is discrete, we can use a network with softmax output do describe the distribution.
# The core idea of training the policy network is quite simple: *we want to maximize the expected total reward by increasing the probability of good actions and decreasing the probability of bad actions*.
#
# To achieve this, we apply the gradient of the expected discounted total reward (return):
#
# $$
# \begin{align}
# \nabla_\theta \mathbb{E}[R|\theta] &= \nabla_\theta \int p_\theta(a|s) R({a}) \, da \\
# &= \int \nabla_\theta p_\theta(a|s) R(a)  \, da \\
# &= \int p_\theta(a|s) \nabla_\theta \log p_\theta(a|s) R(a) \, da \\
# &= \mathbb{E}[\nabla_\theta \log p_\theta(a|s) R(a)]
# \end{align}
# $$
#
# by definition of expectation and using the identity
#
# $$
# \nabla_\theta p_\theta(a|s) = p_\theta(a|s) \nabla_\theta \log p_\theta(a|s) \ .
# $$
#
# The expectation cannot be evaluated analytically, but we have an environment simulator that when supplied with our current policy $p_\theta(a|s)$ can return a sequence of *actions*, *states* and *rewards*. This allows us to replace the integral with a Monte Carlo average:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{T} \sum_{t=0}^T \nabla_\theta \log p_\theta(a_t|s_t) R_t \ ,
# $$
#
# which is our final gradient estimator, also known as REINFORCE. In the Monte Carlo estimator we run the environment simulator for a predefined number of steps with actions chosen stochastically according to the current stochastic action network $p_\theta(a|s)$.

# %% [markdown]
# *Note: For simple reinforcement learning problems (like the one we will address in this exercise) there are simpler methods that work just fine. However, the Policy Gradient method (with some extensions) has been shown to also work well for complex problems with high dimensional inputs and many parameters, where simple methods become inadequate.*

# %% [markdown]
# ## Policy gradient

# %%
# !pip install gymnasium
# !pip install renderlab
# Out:
# Requirement already satisfied: gymnasium in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: renderlab in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (0.1.20230421184216)
# Requirement already satisfied: moviepy in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from renderlab) (1.0.3)
# Requirement already satisfied: gymnasium in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from renderlab) (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium->renderlab) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium->renderlab) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium->renderlab) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium->renderlab) (0.0.4)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from moviepy->renderlab) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from moviepy->renderlab) (4.66.5)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from moviepy->renderlab) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from moviepy->renderlab) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from moviepy->renderlab) (2.35.1)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from moviepy->renderlab) (0.5.1)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from imageio<3.0,>=2.5->moviepy->renderlab) (10.4.0)
# Requirement already satisfied: setuptools in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy->renderlab) (72.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy->renderlab) (0.4.6)

# %% [markdown]
#  **If run on your local machine**, you may need to install `gymnasium[classic-control]` by running the following line:

# %%
# !pip install "gymnasium[classic-control]"
# Out:
# Requirement already satisfied: gymnasium[classic-control] in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium[classic-control]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium[classic-control]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium[classic-control]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium[classic-control]) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\chens\appdata\local\programs\python\python312\lib\site-packages (from gymnasium[classic-control]) (2.6.1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import gymnasium as gym
import renderlab as rl

# %% [markdown]
# First we create the environment:

# %%
env = gym.make('CartPole-v1') # Create environment

# %% [markdown]
# A state in this environment is four numbers describing the position and speed of the cart along with the angle and angular speed of the pole.
#
# There are two available actions: push the cart *left* or *right* encoded as 0 and 1.

# %%
s, _ = env.reset()
a = env.action_space.sample()
print('sample state:', s)
print('sample action:', a )
# Out:
# sample state: [-0.03095742 -0.02123179  0.01534408 -0.00677693]
# sample action: 1

# %% [markdown]
# Let us see how the environment looks when we just take random actions. Note that the episode ends when the pole either 1) is more than 15 degrees from vertical, 2) more outside of the frame or 3) the pole is successfully balanced for some fixed duration.

# %%
env = gym.make("CartPole-v1", render_mode = "rgb_array") # Create environment
env = rl.RenderFrame(env, "./output") # To display environment in the notebook
env.reset() # Reset environment

# Run environment
while True:
    action = env.action_space.sample() # Get a random action
    _, _, done, _, _ = env.step(action) # Take a step
    if done: break # Break if environment is done

env.close() # Close environment
env.play()
# Out:
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# Taking random actions does not do a very good job at balancing the pole. Let us now apply the Policy Gradient method described above to solve this task!
#
# Let's first define our network and helper functions.

# %%
class PolicyNet(nn.Module):
    """Policy network"""

    def __init__(self, n_inputs, n_hidden, n_outputs, learning_rate):
        super(PolicyNet, self).__init__()
        # network
        self.hidden = nn.Linear(n_inputs, n_hidden)
        self.hidden_2 = nn.Linear(n_hidden, n_hidden)
        self.out = nn.Linear(n_hidden, n_outputs)
        # training
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x):
        x = self.hidden(x)
        x = F.relu(x)
        x = self.hidden_2(x)
        x = F.relu(x)
        x = self.out(x)
        return F.softmax(x, dim=1)
    
    def loss(self, action_probabilities, returns):
        return -torch.mean(torch.mul(torch.log(action_probabilities), returns))

# %%
def compute_returns(rewards, discount_factor):
    """Compute discounted returns."""
    returns = np.zeros(len(rewards))
    returns[-1] = rewards[-1]
    for t in reversed(range(len(rewards)-1)):
        returns[t] = rewards[t] + discount_factor * returns[t+1]
    return returns

# %% [markdown]
# To start with, our policy will be a rather simple neural network with one hidden layer. We can retrieve the shape of the state space (input) and action space (output) from the environment.

# %%
n_inputs = env.observation_space.shape[0]
# n_hidden = 20
# n_hidden = 32
n_hidden = 12
n_outputs = env.action_space.n

print('state shape:', n_inputs)
print('action shape:', n_outputs)
# Out:
# state shape: 4
# action shape: 2

# %%
# training settings

# num_episodes = 800
num_episodes = 1000
rollout_limit = 500 # max rollout length
# discount_factor = 1.0 # reward discount factor (gamma), 1.0 = no discount
# discount_factor = 0.90 # reward discount factor (gamma), 1.0 = no discount
# discount_factor = 0.95 # reward discount factor (gamma), 1.0 = no discount
discount_factor = 0.98 # reward discount factor (gamma), 1.0 = no discount
# learning_rate = 0.001 # you know this by now
# learning_rate = 0.005 # you know this by now
learning_rate = 0.003 # you know this by now
learning_rate = 0.01 # you know this by now
val_freq = 100 # validation frequency

# setup policy network

policy = PolicyNet(n_inputs, n_hidden, n_outputs, learning_rate)

# train policy network

try:
    training_rewards, losses = [], []
    print('start training')
    for i in range(num_episodes):
        rollout = []
        s, _ = env.reset()
        for j in range(rollout_limit):
            # generate rollout by iteratively evaluating the current policy on the environment
            with torch.no_grad():
                a_prob = policy(torch.from_numpy(np.atleast_2d(s)).float())
                a = torch.multinomial(a_prob, num_samples=1).squeeze().numpy()
            s1, r, done, _, _ = env.step(a)
            rollout.append((s, a, r))
            s = s1
            if done: break
        # prepare batch
        states, actions, rewards, = zip(*rollout)
        states = np.vstack(states)
        actions = np.vstack(actions)
        rewards = np.array(rewards, dtype=float)
        returns = compute_returns(rewards, discount_factor)
        # policy gradient update
        policy.optimizer.zero_grad()
        a_probs = policy(torch.from_numpy(states).float()).gather(1, torch.from_numpy(actions)).view(-1)
        loss = policy.loss(a_probs, torch.from_numpy(returns).float())
        loss.backward()
        policy.optimizer.step()
        # bookkeeping
        training_rewards.append(sum(rewards))
        losses.append(loss.item())
        # print
        if (i+1) % val_freq == 0:
            # validation
            validation_rewards = []
            for _ in range(10):
                s, _ = env.reset()
                reward = 0
                for _ in range(rollout_limit):
                    with torch.no_grad():
                        a_prob = policy(torch.from_numpy(np.atleast_2d(s)).float())
                        a = a_prob.argmax().item()
                    s, r, done, _, _ = env.step(a)
                    reward += r
                    if done: break
                validation_rewards.append(reward)
            print('{:4d}. mean training reward: {:6.2f}, mean validation reward: {:6.2f}, mean loss: {:7.4f}'.format(i+1, np.mean(training_rewards[-val_freq:]), np.mean(validation_rewards), np.mean(losses[-val_freq:])))
    print('done')
except KeyboardInterrupt:
    print('interrupt')
# Out:
# start training
#  100. mean training reward:  20.97, mean validation reward:   9.40, mean loss:  6.5155
#  200. mean training reward:  22.21, mean validation reward:  24.90, mean loss:  6.8230
#  300. mean training reward:  25.86, mean validation reward:  32.10, mean loss:  7.5564
#  400. mean training reward:  45.11, mean validation reward: 185.20, mean loss: 10.5123
#  500. mean training reward: 112.05, mean validation reward: 311.00, mean loss: 16.3940
#  600. mean training reward: 105.53, mean validation reward: 211.80, mean loss: 15.5422
#  700. mean training reward: 138.61, mean validation reward: 126.70, mean loss: 16.7051
#  800. mean training reward:  76.08, mean validation reward: 187.40, mean loss: 11.9440
#  900. mean training reward: 193.64, mean validation reward: 202.50, mean loss: 20.9444
# 1000. mean training reward: 255.56, mean validation reward: 424.20, mean loss: 22.8187
# done

# %%
# plot results
def moving_average(a, n=10) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret / n

plt.figure(figsize=(16,6))
plt.subplot(211)
plt.plot(range(1, len(training_rewards)+1), training_rewards, label='training reward')
plt.plot(moving_average(training_rewards))
plt.xlabel('episode'); plt.ylabel('reward')
plt.xlim((0, len(training_rewards)))
plt.legend(loc=4); plt.grid()
plt.subplot(212)
plt.plot(range(1, len(losses)+1), losses, label='loss')
plt.plot(moving_average(losses))
plt.xlabel('episode'); plt.ylabel('loss')
plt.xlim((0, len(losses)))
plt.legend(loc=4); plt.grid()
plt.tight_layout(); plt.show()

# %% [markdown]
# Now let's review the solution!

# %%
env = rl.RenderFrame(env, "./gym-results") # Create wrapper to display environment
s,_ = env.reset()

for _ in range(500):
    a = policy(torch.from_numpy(np.atleast_2d(s)).float()).argmax().item()
    s, r, done, _, _ = env.step(a)
    if done: break

env.play()
# Out:
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Reducing variance
#
# By default, this gradient estimator has high variance and therefore variance reduction becomes important to learn more complex tasks.
# We can reduce variance by subtracting a baseline from the returns, which is unbiased in expectation:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{T} \sum_{t=0}^T \nabla_\theta \log p_\theta(a_t|s_t) (R_t-b_t) \ ,
# $$
#
# where the baseline, $b_t$, is estimated by the return a timestep $t$ averaged over $V$ rollouts.
#
# $$
# b_t = \frac{1}{V} \sum_{v=1}^V R_t^{(v)} \ .
# $$

# %% [markdown]
# ## Exercises
#
# Now it is your turn! Make sure you read and understand the code, then play around with it and try to make it learn better and faster.
#
# Experiment with the:
#
# * number of episodes
# * discount factor
# * learning rate
# * network layers
#
#
# ### Exercise 1
#
# *Describe any changes you made to the code and why you think they improve the agent. Are you able to get solutions consistently?*
#
# <h2 style="color: white;">Solution 1</h2>
#
#
#
# Discount factor :
#
#     A discount factor of 0.9 placed too much emphasis on immediate rewards, hindering agent performance.
#
#     Switching to 0.98 improved performance by better accounting for future rewards.
#
# Network Complexity :
#
#     Adding more hidden units and an extra hidden layer initially didn’t improve the model, but offered potential for capturing complex patterns.
#
#     Reducing hidden units while keeping the extra layer achieved a balance, potentially preventing overfitting and optimizing the parameter space.
#
# Learning Rate Adjustment :
#
#     Adjusting the learning rate(0.003) improved model performance
#
# Are you able to get solutions consistently?
#
#     No, for example when I added too many hidden units or put a lower discount factor 0.9 or even a high learning rate, these adjustments will cause an overfitting in the model, thus leading to a poor outcome.
#
# ### Exercise 2
#
# *Consider the following sequence of rewards produced by an agent interacting with an environment for 10 timesteps:*
#
# [0, 1, 1, 1, 0, 1, 1, 0, 0, 0]
#
# * *What is the total reward?*
# * *What is the total future reward in each timestep?*
# * *What is the discounted future reward in each timestep if $\gamma = 0.9$?*
#
# *Hint: See introdution notebook.*
#
# <h2 style="color: white;">Solution 2</h2>
#
# > The total reward is the sum of individual rewards, which in this case is 5:
# $$
# R=\sum_t r_t=5.
# $$
#
# > The total future reward is the reverse cumulative sum:
# $$
# R_t = \sum_{k=0}^{T-t} r_{t+k},
# $$
# so we get the sequence [5, 5, 4, 3, 2, 2, 1, 0, 0, 0].
#
# > In the discounted future reward, we have
# $$
# R_t = \sum_{k=0}^{T-t} \gamma^k r_{t+k},
# $$
# so we instead get the sequence
# >
# > [3.56, 3.96, 3.29, 2.54, 1.71, 1.90, 1.00, 0.00, 0.00, 0.00].
#
# ### Exercise 3
#
# *In the training output, you will sometimes observe the validation reward starts out lower than the training reward but as training progresses they cross over and the validation reward becomes higher than the training reward. How can you explain this behavior?*
#
# *Hint: Do we use the policy network in the same way during training and validation?*
#
# <h2 style="color: white;">Solution 3</h2>
#
#
# This behavior can occur because, at the start of training, the model is likely overfitting to the training data, focusing on specific patterns without generalizing well to unseen data, which results in a lower validation reward. As training progresses, the model improves its ability to generalize by learning more robust patterns, which leads to an increase in validation reward, sometimes surpassing the training reward as it performs better on the validation set due to reduced overfitting.
#
# ### Exercise 4
#
# *How does the policy gradient method we have used address the exploration-exploitation dilemma?*
#
# *Hint: See the introduction notebook about exploration-exploitation.*
#
# <h2 style="color: white;">Solution 4</h2>
#
# > In the policy gradient method, actions are chosen according to a multinomial distribution based on the probabilities output by the network's SoftMax layer. As the network improves, the probabilities will be adjusted, but still be able to sample actions that have low probabilities due to the multinomial function.
#
# ### Exercise 5 [optional]
#
# Extend the code above to reduce variance of the gradient estimator by computing and subtracting the baseline estimate.
#
# *Hint: You need to sample a batch of rollouts (now we sample just one) for each update in order to compute the baseline, $b_t$.*

# %% [markdown]
# ### Exercise from the book by Michael Nielsen
# From chapter 3: *As discussed above, one way of expanding the MNIST training data is to use small rotations of training images. What's a problem that might occur if we allow arbitrarily large rotations of training images?*
#
# **Answer:**
#
# > A problem with arbitrarily large rotations is that not all numbers are invariant to rotations, i.e. a rotation of some number might be the same as another rotation of another number. The obvious example is 6, which is a 180 degrees rotation of 9, and vice versa.
